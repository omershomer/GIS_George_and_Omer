# %%
#Importing the libraries that we will be using. 
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# /opt/conda/lib/python3.9/site-packages/geopandas/_compat.py:106: UserWarning: The Shapely GEOS version (3.9.1-CAPI-1.14.2) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(

# %%
HIN=gpd.read_file('data/LA County Bikeways/High_Injury_Network.geojson')

# %%
HIN.tail()
# Out:
#      OBJECTID             STNAME    Shape_Leng    Shape_Le_1  \
# 381       382      FALLBROOK AVE  12154.897031  12154.897031
# 382       383        ROSCOE BLVD  33846.193933  33846.193933
# 383       384      DEVONSHIRE ST    694.881296    694.881296
# 384       385             9TH ST   6512.938971   6512.938971
# 385       386  PACIFIC COAST HWY   8441.851539   8441.851539
#
#                   FROM_               TO_  \
# 381        VICTORY BLVD       ROSCOE BLVD
# 382      TOPANGA CANYON       BALBOA BLVD
# 383
# 384         FIGUEROA ST        GLADYS AVE
# 385  TEMESCAL CANYON RD  SAN VICENTE BLVD
#
#                                  GlobalID  \
# 381  945d99dc-bd3f-45dd-b7c7-c48c59e4ada2
# 382  c69ec5cb-e3cd-4e87-9d99-f1a079472bb7
# 383  49aeee6a-0a3f-43e3-9b4e-659306499c7e
# 384  6b527c10-adb7-444d-b76d-c60a38ca572a
# 385  47daa246-e2c0-4e25-a650-c840f4db9c33
#
#                                               geometry
# 381  LINESTRING (-118.62347 34.21939, -118.62346 34...
# 382  LINESTRING (-118.59753 34.21980, -118.60608 34...
# 383  LINESTRING (-118.50354 34.25753, -118.50249 34...
# 384  LINESTRING (-118.26284 34.04619, -118.26199 34...
# 385  LINESTRING (-118.51705 34.02687, -118.51789 34...

# %%
HIN.plot(figsize=(12,12))
# Out:
# <AxesSubplot:>
